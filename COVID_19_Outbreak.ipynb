# %% [markdown]
# <a href="https://colab.research.google.com/github/estrelmm/Data-Science/blob/master/COVID_19_Outbreak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Data Science na Prática 2.0**
# *by [sigmoidal.ai](https://sigmoidal.ai)*
#
# ---

# %% [markdown]
# # COVID-19 Outbreak Situation - Overview World and Brazil
#
# COVID-19 - Coronavirus disease is an infectious disease caused by a newly discovered virus. It can be spread primarily when an infected person coughs or sneezes next to someone non-infected. The symptoms may vary from each person, but is known that an infected will experience mild to a moderate respiratory disorder, other cases it will produce no symptoms.
#
# Best practices were recommended by W.H.O to prevent and slow down the transmission such as by protecting yourself and others, using a face mask, regularly washing your hands and not touching your face where the virus can easily access the immune system.
#
#
#
# <center><img alt="Colaboratory logo" width="70%" src="https://raw.githubusercontent.com/carlosfab/dsnp2/master/img/covid19.jpg"></center>
#
# By now, there is no specific treatment proven to be able to kill the virus, nor either, an effective vaccine able to protect people. Governments are processing tests, trials and following the guidance to control the number of deaths.

# %% [markdown]
# ## COVID-19 Dataset
#
# The Dataset - The importance of Data is essential for understanding the facts and statistics collected during the event occurs, therefore, with a good source of data we can measure a wide range in order to guide for better decisions. Since the beginning of the Covid-19 outbreak, many countries have reported the number of cases, tests and deaths according to their databases, which become hard to have only one reliable dataset. The best available data of this pandemic is far from perfect.
#
#
# Tha dataset was compiled by the [Our World in Data Organization](https:/https://ourworldindata.org/coronavirus/)
#
# **Our World in Data and the SDG-Tracker** are collaborative efforts between researchers at the University of Oxford, who are the scientific editors of the website content; and the non-profit organization Global Change Data Lab, who publishes and maintains the website and the data tools.
#
# This dataset is updated until 20/07/2020

# %% [markdown]
# **Variable Dictionary**
#
# * **iso_code**: 	ISO 3166-1 alpha-3 - three-letter country codes
# * **continent**:	Continent of the geographical location
# * **location**: 	Geographical location
# * **date**:	Date of observation
# * **total_cases**:	Total confirmed cases of COVID-19
# * **new_cases**:	New confirmed cases of COVID-19
# * **total_deaths**:	Total deaths attributed to COVID-19
# * **new_deaths**:	New deaths attributed to COVID-19
# * **total_cases_per_million**:	Total confirmed cases of COVID-19 per 1,000,000 people
# * **new_cases_per_million**:	New confirmed cases of COVID-19 per 1,000,000 people
# * **total_deaths_per_million**:	Total deaths attributed to COVID-19 per 1,000,000 people
# * **new_deaths_per_million**:	New deaths attributed to COVID-19 per 1,000,000 people
# * **total_tests**:	Total tests for COVID-19
# * **new_tests**:	New tests for COVID-19
# * **new_tests_smoothed**:	New tests for COVID-19 (7-day smoothed). For countries that don't report testing data on a daily basis, we assume that testing changed equally on a daily basis over any periods in which no data was reported. This produces a complete series of daily figures, which is then averaged over a rolling 7-day window
# * **total_tests_per_thousand**:	Total tests for COVID-19 per 1,000 people
# * **new_tests_per_thousand**:	New tests for COVID-19 per 1,000 people
# * **new_tests_smoothed_per_thousand**:	New tests for COVID-19 (7-day smoothed) per 1,000 people
# * **tests_units**	Units used by the location to report its testing data
# * **stringency_index**:	Government Response Stringency Index: composite measure based on 9 response indicators including school closures, workplace closures, and travel bans, rescaled to a value from 0 to 100 (100 = strictest response)
# * **population**:	Population in 2020
# * **population_density**:	Number of people divided by land area, measured in square kilometers, most recent year available
# * **median_age**:	Median age of the population, UN projection for 2020
# * **aged_65_older**:	Share of the population that is 65 years and older, most recent year available
# * **aged_70_older**:	Share of the population that is 70 years and older in 2015
# * **gdp_per_capita**:	Gross domestic product at purchasing power parity (constant 2011 international dollars), most recent year available
# * **extreme_poverty**:	Share of the population living in extreme poverty, most recent year available since 2010
# * **cvd_death_rate**:	Death rate from cardiovascular disease in 2017
# * **diabetes_prevalence**:	Diabetes prevalence (% of population aged 20 to 79) in 2017
# * **female_smokers**:	Share of women who smoke, most recent year available
# * **male_smokers**:	Share of men who smoke, most recent year available
# * **handwashing_facilities**	Share of the population with basic handwashing facilities on premises, most recent year available
# * **hospital_beds_per_thousand**	Hospital beds per 1,000 people, most recent year available since 2010
# * **life_expectancy**:	Life expectancy at birth in 2019

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')



df = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv')

# %% [markdown]
# ## Introducing the Dataset
#
# We first examine the dataset layout, to acknowledge it's size, shape, columns, types, the percentage of null values.
# Once have it done, its easy to make decisions needed to explore the statistics and so on.
#
# This dataset has 32.125 lines and 34 columns(variables)

# %%
df.shape
# Out:
# (32125, 34)

# %%
df.head()
# Out:
#   iso_code continent  ... hospital_beds_per_thousand life_expectancy
# 0      AFG      Asia  ...                        0.5           64.83
# 1      AFG      Asia  ...                        0.5           64.83
# 2      AFG      Asia  ...                        0.5           64.83
# 3      AFG      Asia  ...                        0.5           64.83
# 4      AFG      Asia  ...                        0.5           64.83
#
# [5 rows x 34 columns]

# %%
df.tail()
# Out:
#       iso_code continent  ... hospital_beds_per_thousand life_expectancy
# 32120      NaN       NaN  ...                        NaN             NaN
# 32121      NaN       NaN  ...                        NaN             NaN
# 32122      NaN       NaN  ...                        NaN             NaN
# 32123      NaN       NaN  ...                        NaN             NaN
# 32124      NaN       NaN  ...                        NaN             NaN
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy'],
#       dtype='object')

# %%
df.date = pd.to_datetime(df.date)

# %%
df.date.max()
# Out:
# Timestamp('2020-07-23 00:00:00')

# %%
df.dtypes
# Out:
# iso_code                                   object
# continent                                  object
# location                                   object
# date                               datetime64[ns]
# total_cases                               float64
# new_cases                                 float64
# total_deaths                              float64
# new_deaths                                float64
# total_cases_per_million                   float64
# new_cases_per_million                     float64
# total_deaths_per_million                  float64
# new_deaths_per_million                    float64
# total_tests                               float64
# new_tests                                 float64
# total_tests_per_thousand                  float64
# new_tests_per_thousand                    float64
# new_tests_smoothed                        float64
# new_tests_smoothed_per_thousand           float64
# tests_units                                object
# ...

# %%
(df.isnull().sum().sort_values(ascending=False))
# Out:
# new_tests                          22410
# new_tests_per_thousand             22410
# total_tests_per_thousand           22138
# total_tests                        22138
# new_tests_smoothed_per_thousand    21244
# new_tests_smoothed                 21244
# tests_units                        20479
# handwashing_facilities             18913
# extreme_poverty                    13017
# male_smokers                        9393
# female_smokers                      9119
# stringency_index                    6166
# hospital_beds_per_thousand          5787
# aged_65_older                       3617
# gdp_per_capita                      3547
# aged_70_older                       3348
# median_age                          3199
# cardiovasc_death_rate               3183
# diabetes_prevalence                 2211
# population_density                  1441
# life_expectancy                      448
# new_deaths_per_million               387
# total_deaths_per_million             387
# ...

# %% [markdown]
# ### **The World COVID-19 Outbreak**
#
# The Covid-19 disease was first identified in Wuhan in China and because of its rapid spread, on March 11, 2020, was officially declared a pandemic by W.H.O.
#
#
# <center><img alt="COVID_19 Timeline" width="70%" src="https://raw.githubusercontent.com/estrelmm/Data-Science/master/Covid-19%20timeline.png"></center>
#
# [Source: thepathologist.com](https:/thepathologist.com/subspecialties/the-pandemic-to-date/)
#
# Experts say that this is a pandemic hasn't seen for over a century. Countries were forced to close their borders, locking down their citizens and promoting self-isolation, restrictions were given only to essential businesses to keep working, some of the strategies to ensure capacity to their health systems.

# %%
df.loc[df.date == '2020-07-05'].sort_values(by="total_cases", ascending=False)
# Out:
#        iso_code      continent  ... hospital_beds_per_thousand life_expectancy
# 32042  OWID_WRL            NaN  ...                      2.705           72.58
# 30541       USA  North America  ...                      2.770           78.86
# 4310        BRA  South America  ...                      2.200           75.88
# 24218       RUS         Europe  ...                      8.050           72.58
# 13613       IND           Asia  ...                      0.530           69.66
# ...         ...            ...  ...                        ...             ...
# 19865       MSR  North America  ...                        NaN           74.16
# 4429        VGB  North America  ...                        NaN           79.07
# 3857        BES  North America  ...                        NaN           77.79
# 890         AIA  North America  ...                        NaN           81.88
# 13069       HKG           Asia  ...                        NaN           84.86
#
# [211 rows x 34 columns]

# %%
df.loc[df.date == '2020-07-01'].sort_values(by="total_deaths", ascending=False)
# Out:
#        iso_code      continent  ... hospital_beds_per_thousand life_expectancy
# 32038  OWID_WRL            NaN  ...                      2.705           72.58
# 30537       USA  North America  ...                      2.770           78.86
# 4306        BRA  South America  ...                      2.200           75.88
# 30331       GBR         Europe  ...                      2.540           81.32
# 14959       ITA         Europe  ...                      3.180           83.51
# ...         ...            ...  ...                        ...             ...
# 5140        KHM           Asia  ...                      0.800           69.82
# 24596       LCA  North America  ...                      1.300           76.20
# 3853        BES  North America  ...                        NaN           77.79
# 24718       VCT  North America  ...                      2.600           72.53
# 13065       HKG           Asia  ...                        NaN           84.86
#
# [211 rows x 34 columns]

# %% [markdown]
# Despite the actions taken, the Global number has over **600.000 Deaths** reported and reached over **15 million cases** around the world, so far.

# %%
#evolution of deaths number  


df.loc[df.location == "World", "total_deaths"].reset_index(drop=True).plot()
plt.title('Global Deaths Evolution')

plt.show()

# %%
df.loc[df.location == "World", "total_cases"].reset_index(drop=True).plot()
plt.title('Global Cases Evolution')

plt.show()

# %% [markdown]
# The charts below are the Top 5 countries of the number of Cases and Deaths (updated 20th of July). The United States and Brazil have been the two most impacted, so far.
#
# Some News has reported that US and Brazil account nearly 40% of the world's total cases and they are most prominent failed countries in the fight against the virus, because the Government has downplayed the virus, causing ,even more a hard situation.

# %%
# Top 5 Countries in Cases and Deaths
top5_total_cases = df.loc[df.date == '2020-07-20', ['location', 'total_cases']].sort_values(by="total_cases", ascending=False)[1:6]
top5_total_deaths = df.loc[df.date == '2020-07-20', ['location', 'total_deaths']].sort_values(by="total_deaths", ascending=False)[1:6]

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 8))

# Plot Top 5 Countries in Cases

ax[0].bar('location', 'total_cases', data=top5_total_cases)
ax[0].set_title("Top 5 Countries in Cases")

# Plot Top 5 Countries in Deaths

ax[1].bar('location', 'total_deaths', data=top5_total_deaths, color='red')
ax[1].set_title("Top 5 Countries in Deaths")

sns.set()

plt.tight_layout();

# %% [markdown]
# **Smokers** - This dataset brings out that 75% are Male Smokers, according to W.H.O that researches suggest that smokers are at higher risk of developing severe COVID-19 outcomes and death because smoking any kind of tobacco reduces lung capacity and increases the risk of many respiratory infections and can increase the severity of respiratory diseases. COVID-19 is an infectious disease that primarily attacks the lungs.

# %%
print("Total Smokers:", df.male_smokers.sum() + df.female_smokers.sum())
print("Total Male Smokers:", df.male_smokers.sum())
print("Total Female Smokers:", df.female_smokers.sum())
# Out:
# Total Smokers: 995243.3139999999
# Total Male Smokers: 742040.6099999999
# Total Female Smokers: 253202.704

# %%
print("% Male Smokers:", df.male_smokers.sum() / (df.male_smokers.sum() + df.female_smokers.sum())*100)
print("% Female Smokers:", df.female_smokers.sum() / (df.male_smokers.sum() + df.female_smokers.sum())*100)
# Out:
# % Male Smokers: 74.55871338815143
# % Female Smokers: 25.441286611848568

# %%
# !pip install pywaffle -q

from pywaffle import Waffle
# Out:
#      |████████████████████████████████| 532kB 2.8MB/s

# %%
fig = plt.figure(
                FigureClass =Waffle,
                rows=3,
                columns=15,
                values={'Total Smokers': 883144.672,
                    'Male Smokers':657514.38,
                       'Female Smokers': 225630.29200000002},
                 legend={'loc': 'upper left',
                         'bbox_to_anchor': (1.1, 1)},
                 icons='child',
                 font_size=25,
                 icon_legend=True,
                 colors=("#999999","#2196f3","#ff5252"),

)

fig.set_tight_layout(False)
plt.show()
# Out:
# <Waffle size 432x288 with 1 Axes>

# %% [markdown]
# ### **Brazil Outbreak**
#
# The first case reported in Brazil was on Feb, 26. While the first Death was on March,18. The number reached over 81.000 of Deaths and over 2 millions cases, latest reported.
#
# Beyond the pandemic, Brazil faces one of the worst political and economic crisis and experts say that will take a long time to recover from this hard time.

# %%
df_brasil = df.loc[df.location == "Brazil"].copy()

df_brasil.head()
# Out:
#      iso_code      continent  ... hospital_beds_per_thousand life_expectancy
# 4123      BRA  South America  ...                        2.2           75.88
# 4124      BRA  South America  ...                        2.2           75.88
# 4125      BRA  South America  ...                        2.2           75.88
# 4126      BRA  South America  ...                        2.2           75.88
# 4127      BRA  South America  ...                        2.2           75.88
#
# [5 rows x 34 columns]

# %%
df_brasil.date.max()
# Out:
# Timestamp('2020-07-23 00:00:00')

# %% [markdown]
# The first death registered in Brazil was March,18, 2020

# %%
df_brasil.loc[df_brasil['new_deaths'] != 0.0].head(1)
# Out:
#      iso_code      continent  ... hospital_beds_per_thousand life_expectancy
# 4201      BRA  South America  ...                        2.2           75.88
#
# [1 rows x 34 columns]

# %%
df_brasil.loc[df_brasil['new_cases'] != 0.0].head(1)
# Out:
#      iso_code      continent  ... hospital_beds_per_thousand life_expectancy
# 4180      BRA  South America  ...                        2.2           75.88
#
# [1 rows x 34 columns]

# %%
df_brasil.loc[df_brasil['new_deaths'] != 0.0].head(1)
# Out:
#      iso_code      continent  ... hospital_beds_per_thousand life_expectancy
# 4201      BRA  South America  ...                        2.2           75.88
#
# [1 rows x 34 columns]

# %%
x = list(range(206))
z = df_brasil['total_cases']
z2 = df_brasil['total_deaths']

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(9, 7))
ax1.set_title('Brazil Cases')
ax1.set_xlabel('Days')
ax1.set_ylabel('Cases')
ax1.plot(x, z)

ax2.set_title('Brazil Cases (Log)')
ax2.set_xlabel('Days')
ax2.set_ylabel('Cases')
ax2.set_yscale('log')
ax2.plot(x, z)

ax3.set_title('Brazil Deaths')
ax3.set_xlabel('Days')
ax3.set_ylabel('Deaths')
ax3.plot(x, z2)

ax4.set_title('Brazil Deaths (Log)')
ax4.set_xlabel('Days')
ax4.set_ylabel('Deaths')
ax4.set_yscale('log')
ax4.plot(x, z2)
plt.tight_layout()

# %% [markdown]
# Most of the countries have started to easy their economy, opening the border to tourists, taking action to warm up the economy, helping out the small businesses, making effort to reduce the unemployment rate, but also adapting the communal places to keep the precautions of social distancing, wearing of a mask, in order to avoid the second wave of contamination.
#
# By now, what the world expects is to have a positive outcome from vaccine trials.
